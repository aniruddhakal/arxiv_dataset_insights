# %%
import pymongo
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# ### Connecting to Database

# %%
db_name = "arxiv-db"
collection_name = "arxiv-dataset-collection"

db = pymongo.MongoClient(host="localhost", port=21000).get_database(db_name)
collection = db[collection_name]
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:21000'], document_class=dict, tz_aware=False, connect=True), 'arxiv-db'), 'arxiv-dataset-collection')

# %% [markdown]
# ### Querying Documents

# %%
# count
collection.count_documents({})
# Out:
# 2258347

# %%
# fetch one record
record_one = collection.find_one()
record_one
# Out:
# {'_id': ObjectId('64729c935ced617335d85d64'),
#  'id': '0704.0001',
#  'submitter': 'Pavel Nadolsky',
#  'authors': "C. Bal\\'azs, E. L. Berger, P. M. Nadolsky, C.-P. Yuan",
#  'title': 'Calculation of prompt diphoton production cross sections at Tevatron and\n  LHC energies',
#  'comments': '37 pages, 15 figures; published version',
#  'journal-ref': 'Phys.Rev.D76:013009,2007',
#  'doi': '10.1103/PhysRevD.76.013009',
#  'report-no': 'ANL-HEP-PR-07-12',
#  'categories': 'hep-ph',
#  'license': None,
#  'abstract': '  A fully differential calculation in perturbative quantum chromodynamics is\npresented for the production of massive photon pairs at hadron colliders. All\nnext-to-leading order perturbative contributions from quark-antiquark,\ngluon-(anti)quark, and gluon-gluon subprocesses are included, as well as\nall-orders resummation of initial-state gluon radiation valid at\nnext-to-next-to-leading logarithmic accuracy. The region of phase space is\nspecified in which the calculation is most reliable. Good agreement is\ndemonstrated with data from the Fermilab Tevatron, and predictions are made for\nmore detailed tests with CDF and DO data. Predictions are shown for\ndistributions of diphoton pairs produced at the energy of the Large Hadron\nCollider (LHC). Distributions of the diphoton pairs from the decay of a Higgs\nboson are contrasted with those produced from QCD processes at the LHC, showing\nthat enhanced sensitivity to the signal can be obtained with judicious\nselection of events.\n',
#  'versions': [{'version': 'v1', 'created': 'Mon, 2 Apr 2007 19:18:42 GMT'},
#   {'version': 'v2', 'created': 'Tue, 24 Jul 2007 20:10:27 GMT'}],
#  'update_date': '2008-11-26',
#  'authors_parsed': [['Balázs', 'C.', ''],
#   ['Berger', 'E. L.', ''],
#   ['Nadolsky', 'P. M.', ''],
#   ['Yuan', 'C. -P.', '']]}

# %%
# identify fields and their types
type_dict = dict(
    zip(
        record_one.keys(),
        [type(record_one[k]) for k in record_one.keys()]
    )
)

del type_dict['_id']
type_dict
# Out:
# {'id': str,
#  'submitter': str,
#  'authors': str,
#  'title': str,
#  'comments': str,
#  'journal-ref': str,
#  'doi': str,
#  'report-no': str,
#  'categories': str,
#  'license': NoneType,
#  'abstract': str,
#  'versions': list,
#  'update_date': str,
#  'authors_parsed': list}

# %%
from pydantic import BaseModel
from typing import Union, List

class ArxivRecord(BaseModel):
    id: str
    submitter: str
    authors: str
    title: str
    comments: str
    doi: str
    categories: str
    license: Union[None, str]
    abstract: str
    versions: List
    authors_parsed: List
        
    @property
    def categories_list(self):
        return self.categories.split()

# %%
obj = ArxivRecord(**record_one)
obj.categories_list
# Out:
# ['hep-ph']

# %% [markdown]
# ### Explore Unique Categories

# %%
categories = collection.distinct("categories")
categories[:5]
# Out:
# ['acc-phys hep-ex physics.acc-ph',
#  'acc-phys physics.acc-ph',
#  'adap-org astro-ph cond-mat nlin.AO',
#  'adap-org bayes-an nlin.AO',
#  'adap-org chao-dyn cond-mat.stat-mech math.DS nlin.AO nlin.CD physics.bio-ph physics.chem-ph q-bio.PE']

# %%
categories[100:105]
# Out:
# ['astro-ph chao-dyn nlin.CD',
#  'astro-ph chao-dyn nlin.CD physics.flu-dyn',
#  'astro-ph chem-ph',
#  'astro-ph comp-gas nlin.CG',
#  'astro-ph cond-mat']

# %%
categories[200:205]
# Out:
# ['astro-ph cs.NA cs.NE math.NA nlin.CD',
#  'astro-ph cs.NE stat.ML',
#  'astro-ph cs.OH physics.data-an physics.space-ph',
#  'astro-ph gr-qc',
#  'astro-ph gr-qc hep-ex']

# %%
categories[50000:50005]
# Out:
# ['math.OC math.CO math.RT',
#  'math.OC math.CO math.ST stat.TH',
#  'math.OC math.CO q-bio.MN q-bio.QM',
#  'math.OC math.CO q-bio.QM',
#  'math.OC math.CT']

# %%
len(categories)
# Out:
# 76869

# %%
cat_set = set()
[cat_set.update(x.split()) for x in categories]
len(cat_set)
# Out:
# 176

# %%
cat_set
# Out:
# {'acc-phys',
#  'adap-org',
#  'alg-geom',
#  'ao-sci',
#  'astro-ph',
#  'astro-ph.CO',
#  'astro-ph.EP',
#  'astro-ph.GA',
#  'astro-ph.HE',
#  'astro-ph.IM',
#  'astro-ph.SR',
#  'atom-ph',
#  'bayes-an',
#  'chao-dyn',
#  'chem-ph',
#  'cmp-lg',
#  'comp-gas',
#  'cond-mat',
#  'cond-mat.dis-nn',
#  'cond-mat.mes-hall',
#  'cond-mat.mtrl-sci',
#  'cond-mat.other',
#  'cond-mat.quant-gas',
#  'cond-mat.soft',
#  'cond-mat.stat-mech',
#  'cond-mat.str-el',
#  'cond-mat.supr-con',
#  'cs.AI',
#  'cs.AR',
#  'cs.CC',
#  'cs.CE',
#  'cs.CG',
#  'cs.CL',
#  'cs.CR',
#  'cs.CV',
#  'cs.CY',
#  'cs.DB',
#  'cs.DC',
#  'cs.DL',
#  'cs.DM',
#  'cs.DS',
#  'cs.ET',
#  'cs.FL',
#  'cs.GL',
#  'cs.GR',
#  'cs.GT',
#  'cs.HC',
#  'cs.IR',
#  'cs.IT',
#  'cs.LG',
#  'cs.LO',
#  'cs.MA',
#  'cs.MM',
#  'cs.MS',
#  'cs.NA',
#  'cs.NE',
#  'cs.NI',
#  'cs.OH',
#  'cs.OS',
#  'cs.PF',
#  'cs.PL',
#  'cs.RO',
#  'cs.SC',
#  'cs.SD',
#  'cs.SE',
#  'cs.SI',
#  'cs.SY',
#  'dg-ga',
#  'econ.EM',
#  'econ.GN',
#  'econ.TH',
#  'eess.AS',
#  'eess.IV',
#  'eess.SP',
#  'eess.SY',
#  'funct-an',
#  'gr-qc',
#  'hep-ex',
#  'hep-lat',
#  'hep-ph',
#  'hep-th',
#  'math-ph',
#  'math.AC',
#  'math.AG',
#  'math.AP',
#  'math.AT',
#  'math.CA',
#  'math.CO',
#  'math.CT',
#  'math.CV',
#  'math.DG',
#  'math.DS',
#  'math.FA',
#  'math.GM',
#  'math.GN',
#  'math.GR',
#  'math.GT',
#  'math.HO',
#  'math.IT',
#  'math.KT',
#  'math.LO',
#  'math.MG',
#  'math.MP',
#  'math.NA',
#  'math.NT',
#  'math.OA',
#  'math.OC',
#  'math.PR',
#  'math.QA',
#  'math.RA',
#  'math.RT',
#  'math.SG',
#  'math.SP',
#  'math.ST',
#  'mtrl-th',
#  'nlin.AO',
#  'nlin.CD',
#  'nlin.CG',
#  'nlin.PS',
#  'nlin.SI',
#  'nucl-ex',
#  'nucl-th',
#  'patt-sol',
#  'physics.acc-ph',
#  'physics.ao-ph',
#  'physics.app-ph',
#  'physics.atm-clus',
#  'physics.atom-ph',
#  'physics.bio-ph',
#  'physics.chem-ph',
#  'physics.class-ph',
#  'physics.comp-ph',
#  'physics.data-an',
#  'physics.ed-ph',
#  'physics.flu-dyn',
#  'physics.gen-ph',
#  'physics.geo-ph',
#  'physics.hist-ph',
#  'physics.ins-det',
#  'physics.med-ph',
#  'physics.optics',
#  'physics.plasm-ph',
#  'physics.pop-ph',
#  'physics.soc-ph',
#  'physics.space-ph',
#  'plasm-ph',
#  'q-alg',
#  'q-bio',
#  'q-bio.BM',
#  'q-bio.CB',
#  'q-bio.GN',
#  'q-bio.MN',
#  'q-bio.NC',
#  'q-bio.OT',
#  'q-bio.PE',
#  'q-bio.QM',
#  'q-bio.SC',
#  'q-bio.TO',
#  'q-fin.CP',
#  'q-fin.EC',
#  'q-fin.GN',
#  'q-fin.MF',
#  'q-fin.PM',
#  'q-fin.PR',
#  'q-fin.RM',
#  'q-fin.ST',
#  'q-fin.TR',
#  'quant-ph',
#  'solv-int',
#  'stat.AP',
#  'stat.CO',
#  'stat.ME',
#  'stat.ML',
#  'stat.OT',
#  'stat.TH',
#  'supr-con'}

# %% [markdown]
# ### Leading Categories
# - Category at the start of the hierarchy

# %%
leading_categories = set()

[leading_categories.update([x.split()[0]]) for x in categories]
len(leading_categories)
# Out:
# 172

# %%
leading_categories
# Out:
# {'acc-phys',
#  'adap-org',
#  'alg-geom',
#  'ao-sci',
#  'astro-ph',
#  'astro-ph.CO',
#  'astro-ph.EP',
#  'astro-ph.GA',
#  'astro-ph.HE',
#  'astro-ph.IM',
#  'astro-ph.SR',
#  'atom-ph',
#  'bayes-an',
#  'chao-dyn',
#  'chem-ph',
#  'cmp-lg',
#  'comp-gas',
#  'cond-mat',
#  'cond-mat.dis-nn',
#  'cond-mat.mes-hall',
#  'cond-mat.mtrl-sci',
#  'cond-mat.other',
#  'cond-mat.quant-gas',
#  'cond-mat.soft',
#  'cond-mat.stat-mech',
#  'cond-mat.str-el',
#  'cond-mat.supr-con',
#  'cs.AI',
#  'cs.AR',
#  'cs.CC',
#  'cs.CE',
#  'cs.CG',
#  'cs.CL',
#  'cs.CR',
#  'cs.CV',
#  'cs.CY',
#  'cs.DB',
#  'cs.DC',
#  'cs.DL',
#  'cs.DM',
#  'cs.DS',
#  'cs.ET',
#  'cs.FL',
#  'cs.GL',
#  'cs.GR',
#  'cs.GT',
#  'cs.HC',
#  'cs.IR',
#  'cs.IT',
#  'cs.LG',
#  'cs.LO',
#  'cs.MA',
#  'cs.MM',
#  'cs.MS',
#  'cs.NA',
#  'cs.NE',
#  'cs.NI',
#  'cs.OH',
#  'cs.OS',
#  'cs.PF',
#  'cs.PL',
#  'cs.RO',
#  'cs.SC',
#  'cs.SD',
#  'cs.SE',
#  'cs.SI',
#  'cs.SY',
#  'dg-ga',
#  'econ.EM',
#  'econ.GN',
#  'econ.TH',
#  'eess.AS',
#  'eess.IV',
#  'eess.SP',
#  'eess.SY',
#  'funct-an',
#  'gr-qc',
#  'hep-ex',
#  'hep-lat',
#  'hep-ph',
#  'hep-th',
#  'math-ph',
#  'math.AC',
#  'math.AG',
#  'math.AP',
#  'math.AT',
#  'math.CA',
#  'math.CO',
#  'math.CT',
#  'math.CV',
#  'math.DG',
#  'math.DS',
#  'math.FA',
#  'math.GM',
#  'math.GN',
#  'math.GR',
#  'math.GT',
#  'math.HO',
#  'math.KT',
#  'math.LO',
#  'math.MG',
#  'math.NA',
#  'math.NT',
#  'math.OA',
#  'math.OC',
#  'math.PR',
#  'math.QA',
#  'math.RA',
#  'math.RT',
#  'math.SG',
#  'math.SP',
#  'math.ST',
#  'mtrl-th',
#  'nlin.AO',
#  'nlin.CD',
#  'nlin.CG',
#  'nlin.PS',
#  'nlin.SI',
#  'nucl-ex',
#  'nucl-th',
#  'patt-sol',
#  'physics.acc-ph',
#  'physics.ao-ph',
#  'physics.app-ph',
#  'physics.atm-clus',
#  'physics.atom-ph',
#  'physics.bio-ph',
#  'physics.chem-ph',
#  'physics.class-ph',
#  'physics.comp-ph',
#  'physics.data-an',
#  'physics.ed-ph',
#  'physics.flu-dyn',
#  'physics.gen-ph',
#  'physics.geo-ph',
#  'physics.hist-ph',
#  'physics.ins-det',
#  'physics.med-ph',
#  'physics.optics',
#  'physics.plasm-ph',
#  'physics.pop-ph',
#  'physics.soc-ph',
#  'physics.space-ph',
#  'plasm-ph',
#  'q-alg',
#  'q-bio.BM',
#  'q-bio.CB',
#  'q-bio.GN',
#  'q-bio.MN',
#  'q-bio.NC',
#  'q-bio.OT',
#  'q-bio.PE',
#  'q-bio.QM',
#  'q-bio.SC',
#  'q-bio.TO',
#  'q-fin.CP',
#  'q-fin.EC',
#  'q-fin.GN',
#  'q-fin.MF',
#  'q-fin.PM',
#  'q-fin.PR',
#  'q-fin.RM',
#  'q-fin.ST',
#  'q-fin.TR',
#  'quant-ph',
#  'solv-int',
#  'stat.AP',
#  'stat.CO',
#  'stat.ME',
#  'stat.ML',
#  'stat.OT',
#  'supr-con'}

# %% [markdown]
# ### Terminal Categories
# - Category at the bottom of the hierarchy

# %%
terminal_categories = set()

[terminal_categories.update([x.split()[-1]]) for x in categories]
len(terminal_categories)
# Out:
# 164

# %%
terminal_categories
# Out:
# {'astro-ph',
#  'astro-ph.CO',
#  'astro-ph.EP',
#  'astro-ph.GA',
#  'astro-ph.HE',
#  'astro-ph.IM',
#  'astro-ph.SR',
#  'atom-ph',
#  'bayes-an',
#  'chem-ph',
#  'cond-mat',
#  'cond-mat.dis-nn',
#  'cond-mat.mes-hall',
#  'cond-mat.mtrl-sci',
#  'cond-mat.other',
#  'cond-mat.quant-gas',
#  'cond-mat.soft',
#  'cond-mat.stat-mech',
#  'cond-mat.str-el',
#  'cond-mat.supr-con',
#  'cs.AI',
#  'cs.AR',
#  'cs.CC',
#  'cs.CE',
#  'cs.CG',
#  'cs.CL',
#  'cs.CR',
#  'cs.CV',
#  'cs.CY',
#  'cs.DB',
#  'cs.DC',
#  'cs.DL',
#  'cs.DM',
#  'cs.DS',
#  'cs.ET',
#  'cs.FL',
#  'cs.GL',
#  'cs.GR',
#  'cs.GT',
#  'cs.HC',
#  'cs.IR',
#  'cs.LG',
#  'cs.LO',
#  'cs.MA',
#  'cs.MM',
#  'cs.MS',
#  'cs.NA',
#  'cs.NE',
#  'cs.NI',
#  'cs.OH',
#  'cs.OS',
#  'cs.PF',
#  'cs.PL',
#  'cs.RO',
#  'cs.SC',
#  'cs.SD',
#  'cs.SE',
#  'cs.SI',
#  'cs.SY',
#  'econ.EM',
#  'econ.GN',
#  'econ.TH',
#  'eess.AS',
#  'eess.IV',
#  'eess.SP',
#  'eess.SY',
#  'gr-qc',
#  'hep-ex',
#  'hep-lat',
#  'hep-ph',
#  'hep-th',
#  'math.AC',
#  'math.AG',
#  'math.AP',
#  'math.AT',
#  'math.CA',
#  'math.CO',
#  'math.CT',
#  'math.CV',
#  'math.DG',
#  'math.DS',
#  'math.FA',
#  'math.GM',
#  'math.GN',
#  'math.GR',
#  'math.GT',
#  'math.HO',
#  'math.IT',
#  'math.KT',
#  'math.LO',
#  'math.MG',
#  'math.MP',
#  'math.NA',
#  'math.NT',
#  'math.OA',
#  'math.OC',
#  'math.PR',
#  'math.QA',
#  'math.RA',
#  'math.RT',
#  'math.SG',
#  'math.SP',
#  'mtrl-th',
#  'nlin.AO',
#  'nlin.CD',
#  'nlin.CG',
#  'nlin.PS',
#  'nlin.SI',
#  'nucl-ex',
#  'nucl-th',
#  'patt-sol',
#  'physics.acc-ph',
#  'physics.ao-ph',
#  'physics.app-ph',
#  'physics.atm-clus',
#  'physics.atom-ph',
#  'physics.bio-ph',
#  'physics.chem-ph',
#  'physics.class-ph',
#  'physics.comp-ph',
#  'physics.data-an',
#  'physics.ed-ph',
#  'physics.flu-dyn',
#  'physics.gen-ph',
#  'physics.geo-ph',
#  'physics.hist-ph',
#  'physics.ins-det',
#  'physics.med-ph',
#  'physics.optics',
#  'physics.plasm-ph',
#  'physics.pop-ph',
#  'physics.soc-ph',
#  'physics.space-ph',
#  'plasm-ph',
#  'q-alg',
#  'q-bio',
#  'q-bio.BM',
#  'q-bio.CB',
#  'q-bio.GN',
#  'q-bio.MN',
#  'q-bio.NC',
#  'q-bio.OT',
#  'q-bio.PE',
#  'q-bio.QM',
#  'q-bio.SC',
#  'q-bio.TO',
#  'q-fin.CP',
#  'q-fin.EC',
#  'q-fin.GN',
#  'q-fin.MF',
#  'q-fin.PM',
#  'q-fin.PR',
#  'q-fin.RM',
#  'q-fin.ST',
#  'q-fin.TR',
#  'quant-ph',
#  'solv-int',
#  'stat.AP',
#  'stat.CO',
#  'stat.ME',
#  'stat.ML',
#  'stat.OT',
#  'stat.TH',
#  'supr-con'}

# %% [markdown]
# ### Leading and terminal intersection

# %%
intersect_cat = leading_categories & terminal_categories
len(intersect_cat)
# Out:
# 160

# %% [markdown]
# ### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

le = LabelEncoder()
le.fit(list(cat_set))

ohe = OneHotEncoder()
ohe.fit(np.array(list(cat_set)).reshape(-1, 1))
# Out:
# OneHotEncoder()

# %%
categories
# Out:
# ['acc-phys hep-ex physics.acc-ph',
#  'acc-phys physics.acc-ph',
#  'adap-org astro-ph cond-mat nlin.AO',
#  'adap-org bayes-an nlin.AO',
#  'adap-org chao-dyn cond-mat.stat-mech math.DS nlin.AO nlin.CD physics.bio-ph physics.chem-ph q-bio.PE',
#  'adap-org chao-dyn nlin.AO nlin.CD',
#  'adap-org chao-dyn nlin.AO nlin.CD nlin.PS patt-sol',
#  'adap-org chao-dyn nlin.AO nlin.CD physics.med-ph q-bio',
#  'adap-org comp-gas nlin.AO nlin.CG',
#  'adap-org cond-mat hep-lat nlin.AO',
#  'adap-org cond-mat nlin.AO',
#  'adap-org cond-mat nlin.AO nlin.CD',
#  'adap-org cond-mat nlin.AO nlin.PS patt-sol',
#  'adap-org cond-mat nlin.AO nlin.SI solv-int',
#  'adap-org cond-mat nlin.AO physics.optics',
#  'adap-org cond-mat nlin.AO q-bio',
#  'adap-org cond-mat.dis-nn cond-mat.stat-mech nlin.AO physics.bio-ph q-bio.NC',
#  'adap-org cond-mat.dis-nn math.DS nlin.AO nlin.PS patt-sol physics.bio-ph',
#  'adap-org cond-mat.dis-nn nlin.AO',
#  'adap-org cond-mat.soft nlin.AO',
#  'adap-org cond-mat.soft nlin.AO physics.bio-ph q-bio',
#  'adap-org cond-mat.soft nlin.AO q-bio.CB q-bio.MN',
#  'adap-org cond-mat.stat-mech cond-mat.str-el math.DS math.SP nlin.AO',
#  'adap-org cond-mat.stat-mech math-ph math.MP nlin.AO',
#  'adap-org cond-mat.stat-mech nlin.AO',
#  'adap-org cond-mat.stat-mech nlin.AO nlin.CG q-bio',
#  'adap-org cond-mat.stat-mech nlin.AO physics.data-an q-bio.GN',
#  'adap-org cond-mat.stat-mech nlin.AO q-bio',
#  'adap-org cond-mat.stat-mech nlin.AO q-bio.PE',
#  'adap-org cs.NE nlin.AO q-bio.PE',
#  'adap-org cs.NI nlin.AO',
#  'adap-org dg-ga math.DG nlin.AO nlin.SI solv-int',
#  'adap-org hep-lat nlin.AO',
#  'adap-org nlin.AO',
#  'adap-org nlin.AO nlin.PS patt-sol',
#  'adap-org nlin.AO nlin.SI solv-int',
#  'adap-org nlin.AO physics.bio-ph',
#  'adap-org nlin.AO physics.bio-ph q-bio',
#  'adap-org nlin.AO q-bio',
#  'adap-org nlin.AO q-bio.GN',
#  'adap-org nlin.AO q-bio.MN q-bio.PE',
#  'adap-org nlin.AO q-bio.NC',
#  'adap-org nlin.AO q-bio.PE',
#  'alg-geom cond-mat math.AG',
#  'alg-geom cs.IT math.AG math.IT',
#  'alg-geom dg-ga hep-th math.AG math.DG',
#  'alg-geom dg-ga math.AG math.DG',
#  'alg-geom dg-ga math.AG math.DG math.QA q-alg',
#  'alg-geom funct-an hep-th math.AG math.FA',
#  'alg-geom hep-th math.AG',
#  'alg-geom hep-th math.AG math.DG q-alg',
#  'alg-geom hep-th math.AG math.QA nlin.SI q-alg solv-int',
#  'alg-geom hep-th math.AG math.QA q-alg',
#  'alg-geom hep-th math.AG nlin.SI solv-int',
#  'alg-geom math.AC math.AG',
#  'alg-geom math.AC math.AG math.CO',
#  'alg-geom math.AC math.AG q-alg',
#  'alg-geom math.AG',
#  'alg-geom math.AG math.CO',
#  'alg-geom math.AG math.CV',
#  'alg-geom math.AG math.DG q-alg',
#  'alg-geom math.AG math.GT',
#  'alg-geom math.AG math.NA math.OC',
#  'alg-geom math.AG math.QA q-alg',
#  'ao-sci cond-mat physics.ao-ph',
#  'ao-sci physics.ao-ph',
#  'ao-sci physics.ao-ph physics.flu-dyn',
#  'astro-ph',
#  'astro-ph adap-org gr-qc nlin.AO',
#  'astro-ph adap-org hep-ph nlin.AO physics.plasm-ph',
#  'astro-ph adap-org nlin.AO physics.plasm-ph',
#  'astro-ph astro-ph.CO',
#  'astro-ph astro-ph.CO astro-ph.GA physics.plasm-ph',
#  'astro-ph astro-ph.CO astro-ph.HE',
#  'astro-ph astro-ph.CO astro-ph.HE astro-ph.IM',
#  'astro-ph astro-ph.CO gr-qc',
#  'astro-ph astro-ph.CO gr-qc hep-ph hep-th',
#  'astro-ph astro-ph.CO hep-ph',
#  'astro-ph astro-ph.EP',
#  'astro-ph astro-ph.EP astro-ph.IM',
#  'astro-ph astro-ph.EP astro-ph.SR',
#  'astro-ph astro-ph.EP physics.chem-ph',
#  'astro-ph astro-ph.EP physics.geo-ph',
#  'astro-ph astro-ph.GA',
#  'astro-ph astro-ph.GA astro-ph.HE hep-ph',
#  'astro-ph astro-ph.GA gr-qc',
#  'astro-ph astro-ph.HE',
#  'astro-ph astro-ph.HE gr-qc',
#  'astro-ph astro-ph.HE hep-ex hep-ph hep-th physics.ao-ph',
#  'astro-ph astro-ph.IM',
#  'astro-ph astro-ph.IM physics.pop-ph',
#  'astro-ph astro-ph.SR',
#  'astro-ph atom-ph',
#  'astro-ph bayes-an',
#  'astro-ph chao-dyn comp-gas nlin.CD nlin.CG',
#  'astro-ph chao-dyn comp-gas nlin.CD nlin.CG nlin.SI solv-int',
#  'astro-ph chao-dyn cond-mat hep-th nlin.CD',
#  'astro-ph chao-dyn cond-mat nlin.CD',
#  'astro-ph chao-dyn cond-mat.mes-hall cond-mat.stat-mech nlin.CD nucl-th physics.atm-clus',
#  'astro-ph chao-dyn gr-qc nlin.CD',
#  'astro-ph chao-dyn nlin.CD',
#  'astro-ph chao-dyn nlin.CD physics.flu-dyn',
#  'astro-ph chem-ph',
#  'astro-ph comp-gas nlin.CG',
#  'astro-ph cond-mat',
#  'astro-ph cond-mat gr-qc',
#  'astro-ph cond-mat gr-qc hep-ex hep-ph',
#  'astro-ph cond-mat gr-qc hep-ph',
#  'astro-ph cond-mat gr-qc hep-ph hep-th',
#  'astro-ph cond-mat gr-qc hep-th',
#  'astro-ph cond-mat gr-qc nucl-th',
#  'astro-ph cond-mat hep-ex hep-ph nucl-ex physics.geo-ph',
#  'astro-ph cond-mat hep-ex hep-ph nucl-ex physics.ins-det',
#  'astro-ph cond-mat hep-ex nucl-ex physics.bio-ph',
#  'astro-ph cond-mat hep-ph',
#  'astro-ph cond-mat hep-ph hep-th',
#  'astro-ph cond-mat hep-ph nucl-th',
#  'astro-ph cond-mat hep-ph physics.space-ph',
#  'astro-ph cond-mat hep-th',
#  'astro-ph cond-mat math-ph math.MP math.OC nlin.PS',
#  'astro-ph cond-mat math.OC nlin.CD',
#  'astro-ph cond-mat nlin.CD',
#  'astro-ph cond-mat nlin.CD physics.flu-dyn',
#  'astro-ph cond-mat nucl-th',
#  'astro-ph cond-mat physics.atom-ph',
#  'astro-ph cond-mat physics.flu-dyn physics.plasm-ph',
#  'astro-ph cond-mat physics.geo-ph physics.space-ph',
#  'astro-ph cond-mat physics.plasm-ph',
#  'astro-ph cond-mat.dis-nn',
#  'astro-ph cond-mat.dis-nn cond-mat.stat-mech',
#  'astro-ph cond-mat.dis-nn gr-qc hep-ex',
#  'astro-ph cond-mat.mes-hall cond-mat.supr-con',
#  'astro-ph cond-mat.mtrl-sci',
#  'astro-ph cond-mat.mtrl-sci physics.ao-ph',
#  'astro-ph cond-mat.mtrl-sci physics.class-ph physics.geo-ph physics.space-ph',
#  'astro-ph cond-mat.mtrl-sci physics.geo-ph',
#  'astro-ph cond-mat.other',
#  'astro-ph cond-mat.other cond-mat.soft physics.flu-dyn',
#  'astro-ph cond-mat.other gr-qc',
#  'astro-ph cond-mat.other hep-ph hep-th',
#  'astro-ph cond-mat.other physics.atom-ph quant-ph',
#  'astro-ph cond-mat.quant-gas',
#  'astro-ph cond-mat.soft',
#  'astro-ph cond-mat.soft cond-mat.stat-mech physics.ao-ph physics.flu-dyn physics.geo-ph',
#  'astro-ph cond-mat.soft cond-mat.stat-mech physics.flu-dyn',
#  'astro-ph cond-mat.soft hep-ex hep-ph nucl-ex physics.ins-det',
#  'astro-ph cond-mat.soft nlin.CD physics.flu-dyn',
#  'astro-ph cond-mat.soft physics.chem-ph',
#  'astro-ph cond-mat.stat-mech',
#  'astro-ph cond-mat.stat-mech gr-qc',
#  'astro-ph cond-mat.stat-mech gr-qc hep-th',
#  'astro-ph cond-mat.stat-mech gr-qc hep-th physics.data-an',
#  'astro-ph cond-mat.stat-mech hep-ph',
#  'astro-ph cond-mat.stat-mech hep-ph hep-th',
#  'astro-ph cond-mat.stat-mech hep-ph math-ph math.MP',
#  'astro-ph cond-mat.stat-mech hep-th',
#  'astro-ph cond-mat.stat-mech math-ph math.MP',
#  'astro-ph cond-mat.stat-mech math.PR physics.data-an',
#  'astro-ph cond-mat.stat-mech nlin.AO',
#  'astro-ph cond-mat.stat-mech nlin.CD',
#  'astro-ph cond-mat.stat-mech nlin.CD physics.flu-dyn',
#  'astro-ph cond-mat.stat-mech nlin.PS',
#  'astro-ph cond-mat.stat-mech nucl-th',
#  'astro-ph cond-mat.stat-mech nucl-th physics.plasm-ph',
#  'astro-ph cond-mat.stat-mech physics.ao-ph physics.flu-dyn physics.plasm-ph physics.space-ph',
#  'astro-ph cond-mat.stat-mech physics.atom-ph',
#  'astro-ph cond-mat.stat-mech physics.bio-ph',
#  'astro-ph cond-mat.stat-mech physics.bio-ph physics.chem-ph q-bio.BM',
#  'astro-ph cond-mat.stat-mech physics.class-ph',
#  'astro-ph cond-mat.stat-mech physics.comp-ph',
#  'astro-ph cond-mat.stat-mech physics.data-an',
#  'astro-ph cond-mat.stat-mech physics.flu-dyn',
#  'astro-ph cond-mat.stat-mech physics.hist-ph',
#  'astro-ph cond-mat.stat-mech physics.plasm-ph',
#  'astro-ph cond-mat.stat-mech physics.space-ph',
#  'astro-ph cond-mat.str-el hep-ph hep-th',
#  'astro-ph cond-mat.supr-con',
#  'astro-ph cond-mat.supr-con gr-qc',
#  'astro-ph cond-mat.supr-con gr-qc hep-th',
#  'astro-ph cond-mat.supr-con gr-qc nucl-th',
#  'astro-ph cond-mat.supr-con hep-ph nucl-th',
#  'astro-ph cond-mat.supr-con nucl-th',
#  'astro-ph cs.AI physics.soc-ph',
#  'astro-ph cs.CC cs.DS',
#  'astro-ph cs.CE',
#  'astro-ph cs.CG physics.comp-ph',
#  'astro-ph cs.CV physics.data-an',
#  'astro-ph cs.DB cs.DL cs.IR',
#  'astro-ph cs.DC',
#  'astro-ph cs.DC physics.comp-ph',
#  'astro-ph cs.DL',
#  'astro-ph cs.DL physics.soc-ph',
#  'astro-ph cs.DS',
#  'astro-ph cs.GR',
#  'astro-ph cs.GR cs.HC',
#  'astro-ph cs.HC physics.comp-ph',
#  'astro-ph cs.IT hep-th math.IT physics.data-an stat.CO',
#  'astro-ph cs.IT math.IT',
#  'astro-ph cs.LG',
#  'astro-ph cs.NA',
#  'astro-ph cs.NA cs.NE math.NA nlin.CD',
#  'astro-ph cs.NE stat.ML',
#  'astro-ph cs.OH physics.data-an physics.space-ph',
#  'astro-ph gr-qc',
#  'astro-ph gr-qc hep-ex',
#  'astro-ph gr-qc hep-ex hep-ph',
#  'astro-ph gr-qc hep-ex hep-ph hep-th',
#  'astro-ph gr-qc hep-ex hep-ph hep-th math-ph math.MP',
#  'astro-ph gr-qc hep-ex hep-ph nucl-ex nucl-th',
#  'astro-ph gr-qc hep-ex hep-ph nucl-th',
#  'astro-ph gr-qc hep-ex hep-th',
#  'astro-ph gr-qc hep-ex hep-th physics.optics',
#  'astro-ph gr-qc hep-lat hep-ph',
#  'astro-ph gr-qc hep-lat hep-ph hep-th physics.atom-ph',
#  'astro-ph gr-qc hep-ph',
#  'astro-ph gr-qc hep-ph hep-th',
#  'astro-ph gr-qc hep-ph hep-th math-ph math.MP',
#  'astro-ph gr-qc hep-ph hep-th math.QA',
#  'astro-ph gr-qc hep-ph hep-th nlin.CD',
#  'astro-ph gr-qc hep-ph hep-th nucl-th',
#  'astro-ph gr-qc hep-ph hep-th physics.atom-ph',
#  'astro-ph gr-qc hep-ph hep-th physics.class-ph',
#  'astro-ph gr-qc hep-ph hep-th physics.hist-ph',
#  'astro-ph gr-qc hep-ph hep-th physics.pop-ph',
#  'astro-ph gr-qc hep-ph hep-th quant-ph',
#  'astro-ph gr-qc hep-ph nlin.CD',
#  'astro-ph gr-qc hep-ph nucl-ex nucl-th physics.space-ph',
#  'astro-ph gr-qc hep-ph nucl-th',
#  'astro-ph gr-qc hep-ph physics.acc-ph',
#  'astro-ph gr-qc hep-ph physics.ao-ph',
#  'astro-ph gr-qc hep-ph physics.atom-ph',
#  'astro-ph gr-qc hep-ph physics.class-ph',
#  'astro-ph gr-qc hep-ph physics.space-ph',
#  'astro-ph gr-qc hep-ph quant-ph',
#  'astro-ph gr-qc hep-th',
#  'astro-ph gr-qc hep-th math-ph math.MP',
#  'astro-ph gr-qc hep-th math-ph math.MP nlin.PS',
#  'astro-ph gr-qc hep-th math.DS',
#  'astro-ph gr-qc hep-th nucl-th',
#  'astro-ph gr-qc hep-th nucl-th physics.atom-ph',
#  'astro-ph gr-qc hep-th nucl-th quant-ph',
#  'astro-ph gr-qc hep-th physics.atom-ph quant-ph',
#  'astro-ph gr-qc hep-th physics.pop-ph',
#  'astro-ph gr-qc hep-th physics.space-ph',
#  'astro-ph gr-qc hep-th quant-ph',
#  'astro-ph gr-qc math-ph math.AP math.MP',
#  'astro-ph gr-qc math-ph math.MP',
#  'astro-ph gr-qc math-ph math.MP nlin.SI physics.class-ph quant-ph',
#  'astro-ph gr-qc math-ph math.MP nucl-th physics.geo-ph',
#  'astro-ph gr-qc math.AP',
#  'astro-ph gr-qc math.DS',
#  'astro-ph gr-qc nlin.CD',
#  'astro-ph gr-qc nlin.CD nlin.PS',
#  'astro-ph gr-qc nlin.CD physics.flu-dyn',
#  'astro-ph gr-qc nlin.PS',
#  'astro-ph gr-qc nucl-th',
#  'astro-ph gr-qc physics.ao-ph physics.flu-dyn',
#  'astro-ph gr-qc physics.atom-ph',
#  'astro-ph gr-qc physics.class-ph',
#  'astro-ph gr-qc physics.comp-ph',
#  'astro-ph gr-qc physics.comp-ph physics.flu-dyn',
#  'astro-ph gr-qc physics.data-an',
#  'astro-ph gr-qc physics.data-an physics.pop-ph',
#  'astro-ph gr-qc physics.data-an physics.space-ph',
#  'astro-ph gr-qc physics.ed-ph',
#  'astro-ph gr-qc physics.ed-ph physics.pop-ph',
#  'astro-ph gr-qc physics.flu-dyn',
#  'astro-ph gr-qc physics.flu-dyn physics.plasm-ph',
#  'astro-ph gr-qc physics.geo-ph',
#  'astro-ph gr-qc physics.hist-ph',
#  'astro-ph gr-qc physics.plasm-ph',
#  'astro-ph gr-qc physics.pop-ph',
#  'astro-ph gr-qc physics.pop-ph physics.soc-ph',
#  'astro-ph gr-qc physics.soc-ph',
#  'astro-ph gr-qc physics.space-ph',
#  'astro-ph gr-qc quant-ph',
#  'astro-ph hep-ex',
#  'astro-ph hep-ex hep-ph',
#  'astro-ph hep-ex hep-ph hep-th',
#  'astro-ph hep-ex hep-ph math-ph math.MP',
#  'astro-ph hep-ex hep-ph nucl-ex',
#  'astro-ph hep-ex hep-ph nucl-ex nucl-th',
#  'astro-ph hep-ex hep-ph nucl-ex nucl-th physics.chem-ph',
#  'astro-ph hep-ex hep-ph nucl-ex physics.acc-ph',
#  'astro-ph hep-ex hep-ph nucl-th',
#  'astro-ph hep-ex hep-ph nucl-th physics.hist-ph physics.pop-ph',
#  'astro-ph hep-ex hep-ph physics.ins-det',
#  'astro-ph hep-ex hep-ph physics.space-ph',
#  'astro-ph hep-ex hep-ph quant-ph',
#  'astro-ph hep-ex nucl-ex',
#  'astro-ph hep-ex nucl-ex nucl-th',
#  'astro-ph hep-ex nucl-ex physics.ins-det',
#  'astro-ph hep-ex physics.acc-ph physics.ins-det',
#  'astro-ph hep-ex physics.data-an',
#  'astro-ph hep-ex physics.geo-ph',
#  'astro-ph hep-ex physics.ins-det',
#  'astro-ph hep-lat',
#  'astro-ph hep-lat hep-ph',
#  'astro-ph hep-lat hep-ph hep-th',
#  'astro-ph hep-lat hep-ph nucl-th',
#  'astro-ph hep-ph',
#  'astro-ph hep-ph hep-th',
#  'astro-ph hep-ph hep-th nucl-ex nucl-th',
#  'astro-ph hep-ph hep-th nucl-th',
#  'astro-ph hep-ph hep-th quant-ph',
#  'astro-ph hep-ph math-ph math.MP',
#  'astro-ph hep-ph math-ph math.MP physics.chem-ph',
#  'astro-ph hep-ph nlin.CD',
#  'astro-ph hep-ph nucl-ex',
#  'astro-ph hep-ph nucl-ex nucl-th',
#  'astro-ph hep-ph nucl-ex nucl-th physics.hist-ph',
#  'astro-ph hep-ph nucl-ex nucl-th physics.plasm-ph',
#  'astro-ph hep-ph nucl-th',
#  'astro-ph hep-ph nucl-th physics.ao-ph',
#  'astro-ph hep-ph physics.ao-ph',
#  'astro-ph hep-ph physics.ao-ph physics.bio-ph physics.geo-ph',
#  'astro-ph hep-ph physics.ao-ph physics.geo-ph',
#  'astro-ph hep-ph physics.ao-ph physics.geo-ph q-bio.PE',
#  'astro-ph hep-ph physics.atom-ph',
#  'astro-ph hep-ph physics.atom-ph physics.space-ph',
#  'astro-ph hep-ph physics.bio-ph physics.geo-ph',
#  'astro-ph hep-ph physics.data-an',
#  'astro-ph hep-ph physics.ed-ph physics.soc-ph',
#  'astro-ph hep-ph physics.flu-dyn',
#  'astro-ph hep-ph physics.geo-ph',
#  'astro-ph hep-ph physics.ins-det',
#  'astro-ph hep-ph physics.plasm-ph',
#  'astro-ph hep-ph physics.pop-ph',
#  'astro-ph hep-ph physics.space-ph',
#  'astro-ph hep-th',
#  'astro-ph hep-th nucl-th',
#  'astro-ph hep-th physics.atom-ph',
#  'astro-ph hep-th physics.class-ph',
#  'astro-ph hep-th physics.comp-ph',
#  'astro-ph hep-th physics.gen-ph physics.plasm-ph',
#  'astro-ph hep-th quant-ph',
#  'astro-ph math-ph math.DS math.MP nlin.CD',
#  'astro-ph math-ph math.MP',
#  'astro-ph math-ph math.MP nlin.CD physics.class-ph physics.hist-ph',
#  'astro-ph math-ph math.MP nlin.CD physics.class-ph physics.space-ph',
#  'astro-ph math-ph math.MP nlin.CD physics.hist-ph',
#  'astro-ph math-ph math.MP nlin.PS',
#  'astro-ph math-ph math.MP nlin.SI',
#  'astro-ph math-ph math.MP nlin.SI physics.plasm-ph',
#  'astro-ph math-ph math.MP physics.ao-ph',
#  'astro-ph math-ph math.MP physics.atom-ph physics.chem-ph quant-ph',
#  'astro-ph math-ph math.MP physics.class-ph',
#  'astro-ph math-ph math.MP physics.flu-dyn',
#  'astro-ph math-ph math.MP physics.flu-dyn physics.geo-ph physics.plasm-ph physics.space-ph',
#  'astro-ph math-ph math.MP physics.space-ph quant-ph',
#  'astro-ph math.AP',
#  'astro-ph math.DG nlin.CD quant-ph',
#  'astro-ph math.DS',
#  'astro-ph math.DS nlin.CD',
#  'astro-ph math.DS nlin.CD physics.class-ph',
#  'astro-ph math.DS nlin.CD physics.geo-ph',
#  'astro-ph math.DS nlin.CD physics.geo-ph physics.space-ph',
#  'astro-ph math.DS nlin.SI',
#  'astro-ph math.DS nlin.SI physics.class-ph',
#  'astro-ph math.DS nlin.SI physics.geo-ph',
#  'astro-ph math.DS physics.geo-ph',
#  'astro-ph math.NA',
#  'astro-ph math.NA physics.comp-ph',
#  'astro-ph math.RA physics.data-an',
#  'astro-ph math.RT',
#  'astro-ph math.ST stat.TH',
#  'astro-ph nlin.AO',
#  'astro-ph nlin.CD',
#  'astro-ph nlin.CD nucl-th',
#  'astro-ph nlin.CD physics.ao-ph',
#  'astro-ph nlin.CD physics.atom-ph',
#  'astro-ph nlin.CD physics.class-ph physics.space-ph',
#  'astro-ph nlin.CD physics.data-an',
#  'astro-ph nlin.CD physics.data-an physics.flu-dyn',
#  'astro-ph nlin.CD physics.flu-dyn',
#  'astro-ph nlin.CD physics.flu-dyn physics.geo-ph',
#  'astro-ph nlin.CD physics.flu-dyn physics.plasm-ph',
#  'astro-ph nlin.CD physics.geo-ph',
#  'astro-ph nlin.CD physics.hist-ph physics.plasm-ph physics.space-ph',
#  'astro-ph nlin.CD physics.plasm-ph',
#  'astro-ph nlin.CD physics.plasm-ph physics.space-ph',
#  'astro-ph nlin.CD physics.space-ph',
#  'astro-ph nlin.PS',
#  'astro-ph nlin.PS patt-sol',
#  'astro-ph nlin.SI physics.flu-dyn',
#  'astro-ph nucl-ex',
#  'astro-ph nucl-ex nucl-th',
#  'astro-ph nucl-ex physics.ao-ph physics.geo-ph',
#  'astro-ph nucl-ex physics.ins-det',
#  'astro-ph nucl-ex physics.space-ph',
#  'astro-ph nucl-th',
#  'astro-ph nucl-th physics.comp-ph',
#  'astro-ph nucl-th physics.ed-ph',
#  'astro-ph nucl-th physics.flu-dyn',
#  'astro-ph nucl-th physics.hist-ph',
#  'astro-ph nucl-th physics.plasm-ph',
#  'astro-ph physics.acc-ph',
#  'astro-ph physics.acc-ph physics.plasm-ph',
#  'astro-ph physics.ao-ph',
#  'astro-ph physics.ao-ph physics.bio-ph physics.geo-ph physics.space-ph',
#  'astro-ph physics.ao-ph physics.bio-ph physics.geo-ph q-bio.PE',
#  'astro-ph physics.ao-ph physics.flu-dyn physics.geo-ph physics.plasm-ph physics.space-ph',
#  'astro-ph physics.ao-ph physics.geo-ph',
#  'astro-ph physics.ao-ph physics.geo-ph physics.plasm-ph q-bio.PE',
#  'astro-ph physics.ao-ph physics.geo-ph physics.soc-ph',
#  'astro-ph physics.ao-ph physics.geo-ph physics.space-ph',
#  'astro-ph physics.ao-ph physics.geo-ph physics.space-ph q-bio.PE',
#  'astro-ph physics.ao-ph physics.geo-ph q-bio.PE',
#  'astro-ph physics.ao-ph physics.space-ph',
#  'astro-ph physics.ao-ph q-bio.PE',
#  'astro-ph physics.atm-clus',
#  'astro-ph physics.atm-clus physics.chem-ph',
#  'astro-ph physics.atom-ph',
#  'astro-ph physics.atom-ph physics.chem-ph',
#  'astro-ph physics.atom-ph quant-ph',
#  'astro-ph physics.bio-ph',
#  'astro-ph physics.bio-ph physics.hist-ph',
#  'astro-ph physics.bio-ph q-bio',
#  'astro-ph physics.chem-ph',
#  'astro-ph physics.chem-ph quant-ph',
#  'astro-ph physics.class-ph',
#  'astro-ph physics.class-ph physics.geo-ph',
#  'astro-ph physics.class-ph physics.geo-ph physics.hist-ph',
#  'astro-ph physics.comp-ph',
#  'astro-ph physics.comp-ph physics.data-an',
#  'astro-ph physics.comp-ph physics.flu-dyn',
#  'astro-ph physics.comp-ph physics.flu-dyn physics.geo-ph physics.plasm-ph physics.space-ph',
#  'astro-ph physics.comp-ph physics.ins-det',
#  'astro-ph physics.comp-ph physics.plasm-ph',
#  'astro-ph physics.comp-ph physics.plasm-ph quant-ph',
#  'astro-ph physics.data-an',
#  'astro-ph physics.data-an physics.ins-det',
#  'astro-ph physics.data-an physics.plasm-ph physics.space-ph',
#  'astro-ph physics.data-an stat.AP',
#  'astro-ph physics.data-an stat.ML',
#  'astro-ph physics.ed-ph',
#  'astro-ph physics.flu-dyn',
#  'astro-ph physics.flu-dyn physics.geo-ph physics.plasm-ph physics.space-ph',
#  'astro-ph physics.flu-dyn physics.plasm-ph',
#  'astro-ph physics.flu-dyn physics.space-ph',
#  'astro-ph physics.gen-ph',
#  'astro-ph physics.gen-ph physics.optics physics.plasm-ph',
#  'astro-ph physics.geo-ph',
#  'astro-ph physics.geo-ph physics.plasm-ph',
#  'astro-ph physics.geo-ph physics.soc-ph q-bio.PE',
#  'astro-ph physics.geo-ph physics.space-ph',
#  'astro-ph physics.geo-ph q-bio.PE',
#  'astro-ph physics.hist-ph',
#  'astro-ph physics.hist-ph physics.pop-ph',
#  'astro-ph physics.ins-det',
#  'astro-ph physics.ins-det physics.optics',
#  'astro-ph physics.ins-det physics.space-ph',
#  'astro-ph physics.optics',
#  'astro-ph physics.optics physics.space-ph',
#  'astro-ph physics.plasm-ph',
#  'astro-ph physics.plasm-ph physics.space-ph',
#  'astro-ph physics.pop-ph',
#  'astro-ph physics.pop-ph physics.space-ph',
#  'astro-ph physics.soc-ph',
#  'astro-ph physics.space-ph',
#  'astro-ph plasm-ph',
#  'astro-ph q-bio.BM',
#  'astro-ph q-bio.PE',
#  'astro-ph quant-ph',
#  'astro-ph stat.AP',
#  'astro-ph stat.ME',
#  'astro-ph.CO',
#  'astro-ph.CO astro-ph.EP',
#  'astro-ph.CO astro-ph.EP astro-ph.GA',
#  'astro-ph.CO astro-ph.EP astro-ph.GA astro-ph.HE',
#  'astro-ph.CO astro-ph.EP astro-ph.GA astro-ph.IM astro-ph.SR',
#  'astro-ph.CO astro-ph.EP astro-ph.GA hep-ph hep-th',
#  'astro-ph.CO astro-ph.EP astro-ph.GA physics.flu-dyn',
#  'astro-ph.CO astro-ph.EP astro-ph.HE',
#  'astro-ph.CO astro-ph.EP astro-ph.HE astro-ph.IM',
#  'astro-ph.CO astro-ph.EP astro-ph.IM',
#  'astro-ph.CO astro-ph.EP astro-ph.SR',
#  'astro-ph.CO astro-ph.EP astro-ph.SR gr-qc',
#  'astro-ph.CO astro-ph.EP astro-ph.SR hep-th',
#  'astro-ph.CO astro-ph.EP gr-qc hep-ph hep-th',
#  'astro-ph.CO astro-ph.EP hep-ph',
#  'astro-ph.CO astro-ph.EP hep-th',
#  'astro-ph.CO astro-ph.EP nlin.CD',
#  'astro-ph.CO astro-ph.EP physics.chem-ph',
#  'astro-ph.CO astro-ph.GA',
#  'astro-ph.CO astro-ph.GA astro-ph.HE',
#  'astro-ph.CO astro-ph.GA astro-ph.HE astro-ph.IM',
#  'astro-ph.CO astro-ph.GA astro-ph.HE astro-ph.IM gr-qc',
#  'astro-ph.CO astro-ph.GA astro-ph.HE astro-ph.SR',
#  'astro-ph.CO astro-ph.GA astro-ph.HE astro-ph.SR hep-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.HE gr-qc',
#  'astro-ph.CO astro-ph.GA astro-ph.HE gr-qc hep-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.HE gr-qc hep-th',
#  'astro-ph.CO astro-ph.GA astro-ph.HE hep-ex hep-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.HE hep-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.HE hep-ph hep-th',
#  'astro-ph.CO astro-ph.GA astro-ph.HE hep-ph physics.data-an',
#  'astro-ph.CO astro-ph.GA astro-ph.HE hep-ph physics.flu-dyn',
#  'astro-ph.CO astro-ph.GA astro-ph.HE hep-th',
#  'astro-ph.CO astro-ph.GA astro-ph.HE physics.flu-dyn',
#  'astro-ph.CO astro-ph.GA astro-ph.HE physics.flu-dyn physics.plasm-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.HE physics.plasm-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.HE physics.plasm-ph physics.space-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.IM',
#  'astro-ph.CO astro-ph.GA astro-ph.IM astro-ph.SR',
#  'astro-ph.CO astro-ph.GA astro-ph.IM cs.AI cs.LG',
#  'astro-ph.CO astro-ph.GA astro-ph.IM cs.CV cs.LG',
#  'astro-ph.CO astro-ph.GA astro-ph.IM cs.LG',
#  'astro-ph.CO astro-ph.GA astro-ph.IM cs.LG stat.ML',
#  'astro-ph.CO astro-ph.GA astro-ph.IM gr-qc',
#  'astro-ph.CO astro-ph.GA astro-ph.IM gr-qc hep-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.IM gr-qc hep-th',
#  'astro-ph.CO astro-ph.GA astro-ph.IM hep-ex',
#  'astro-ph.CO astro-ph.GA astro-ph.IM hep-ex hep-th',
#  'astro-ph.CO astro-ph.GA astro-ph.IM hep-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.IM hep-ph hep-th',
#  'astro-ph.CO astro-ph.GA astro-ph.IM physics.comp-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.IM physics.comp-ph physics.flu-dyn',
#  'astro-ph.CO astro-ph.GA astro-ph.IM physics.data-an',
#  'astro-ph.CO astro-ph.GA astro-ph.IM stat.AP',
#  'astro-ph.CO astro-ph.GA astro-ph.SR',
#  'astro-ph.CO astro-ph.GA astro-ph.SR gr-qc hep-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.SR gr-qc hep-th',
#  'astro-ph.CO astro-ph.GA astro-ph.SR gr-qc physics.hist-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.SR hep-ph',
#  'astro-ph.CO astro-ph.GA astro-ph.SR nucl-th',
#  'astro-ph.CO astro-ph.GA astro-ph.SR physics.plasm-ph',
#  'astro-ph.CO astro-ph.GA cond-mat.other gr-qc hep-th',
#  'astro-ph.CO astro-ph.GA cond-mat.quant-gas hep-ph',
#  'astro-ph.CO astro-ph.GA cond-mat.quant-gas hep-th',
#  'astro-ph.CO astro-ph.GA cond-mat.stat-mech',
#  'astro-ph.CO astro-ph.GA cond-mat.stat-mech hep-ph',
#  'astro-ph.CO astro-ph.GA cs.LG',
#  'astro-ph.CO astro-ph.GA cs.LG hep-ph',
#  'astro-ph.CO astro-ph.GA cs.LG stat.ML',
#  'astro-ph.CO astro-ph.GA gr-qc',
#  'astro-ph.CO astro-ph.GA gr-qc hep-ex hep-ph',
#  'astro-ph.CO astro-ph.GA gr-qc hep-ph',
#  'astro-ph.CO astro-ph.GA gr-qc hep-ph hep-th',
#  'astro-ph.CO astro-ph.GA gr-qc hep-ph physics.hist-ph',
#  'astro-ph.CO astro-ph.GA gr-qc hep-th',
#  'astro-ph.CO astro-ph.GA gr-qc physics.comp-ph',
#  'astro-ph.CO astro-ph.GA gr-qc physics.data-an',
#  'astro-ph.CO astro-ph.GA gr-qc physics.optics',
#  'astro-ph.CO astro-ph.GA gr-qc physics.pop-ph',
#  'astro-ph.CO astro-ph.GA gr-qc physics.space-ph',
#  'astro-ph.CO astro-ph.GA hep-ex',
#  'astro-ph.CO astro-ph.GA hep-ex hep-ph',
#  'astro-ph.CO astro-ph.GA hep-ex hep-ph nucl-ex',
#  'astro-ph.CO astro-ph.GA hep-ph',
#  'astro-ph.CO astro-ph.GA hep-ph hep-th',
#  'astro-ph.CO astro-ph.GA hep-ph physics.flu-dyn',
#  'astro-ph.CO astro-ph.GA hep-ph physics.optics',
#  'astro-ph.CO astro-ph.GA hep-ph physics.plasm-ph',
#  'astro-ph.CO astro-ph.GA hep-th',
#  'astro-ph.CO astro-ph.GA math-ph math.MP',
#  'astro-ph.CO astro-ph.GA nlin.AO',
#  'astro-ph.CO astro-ph.GA nlin.AO nlin.CD',
#  'astro-ph.CO astro-ph.GA nucl-th',
#  'astro-ph.CO astro-ph.GA physics.atom-ph',
#  'astro-ph.CO astro-ph.GA physics.atom-ph physics.comp-ph',
#  'astro-ph.CO astro-ph.GA physics.class-ph',
#  'astro-ph.CO astro-ph.GA physics.comp-ph',
#  'astro-ph.CO astro-ph.GA physics.comp-ph physics.plasm-ph',
#  'astro-ph.CO astro-ph.GA physics.data-an',
#  'astro-ph.CO astro-ph.GA physics.data-an physics.flu-dyn',
#  'astro-ph.CO astro-ph.GA physics.flu-dyn',
#  'astro-ph.CO astro-ph.GA physics.flu-dyn physics.plasm-ph',
#  'astro-ph.CO astro-ph.GA physics.hist-ph',
#  'astro-ph.CO astro-ph.GA physics.plasm-ph',
#  'astro-ph.CO astro-ph.GA physics.pop-ph',
#  'astro-ph.CO astro-ph.GA physics.pop-ph q-bio.PE',
#  'astro-ph.CO astro-ph.GA stat.CO',
#  'astro-ph.CO astro-ph.HE',
#  'astro-ph.CO astro-ph.HE astro-ph.IM',
#  'astro-ph.CO astro-ph.HE astro-ph.IM astro-ph.SR',
#  'astro-ph.CO astro-ph.HE astro-ph.IM cs.LG',
#  'astro-ph.CO astro-ph.HE astro-ph.IM gr-qc',
#  'astro-ph.CO astro-ph.HE astro-ph.IM hep-ex',
#  'astro-ph.CO astro-ph.HE astro-ph.IM hep-ex hep-ph',
#  'astro-ph.CO astro-ph.HE astro-ph.IM hep-ph',
#  'astro-ph.CO astro-ph.HE astro-ph.IM hep-ph physics.data-an',
#  'astro-ph.CO astro-ph.HE astro-ph.IM hep-ph stat.ML',
#  'astro-ph.CO astro-ph.HE astro-ph.IM stat.AP stat.CO',
#  'astro-ph.CO astro-ph.HE astro-ph.SR',
#  'astro-ph.CO astro-ph.HE astro-ph.SR gr-qc',
#  'astro-ph.CO astro-ph.HE astro-ph.SR hep-ph',
#  'astro-ph.CO astro-ph.HE gr-qc',
#  'astro-ph.CO astro-ph.HE gr-qc hep-ex',
#  'astro-ph.CO astro-ph.HE gr-qc hep-ex hep-ph',
#  'astro-ph.CO astro-ph.HE gr-qc hep-ph',
#  'astro-ph.CO astro-ph.HE gr-qc hep-ph hep-th',
#  'astro-ph.CO astro-ph.HE gr-qc hep-ph nucl-th',
#  'astro-ph.CO astro-ph.HE gr-qc hep-ph physics.atom-ph',
#  'astro-ph.CO astro-ph.HE gr-qc hep-th',
#  'astro-ph.CO astro-ph.HE gr-qc nucl-th',
#  'astro-ph.CO astro-ph.HE hep-ex',
#  'astro-ph.CO astro-ph.HE hep-ex hep-ph',
#  'astro-ph.CO astro-ph.HE hep-ex hep-ph hep-th',
#  'astro-ph.CO astro-ph.HE hep-ex hep-ph nucl-th',
#  'astro-ph.CO astro-ph.HE hep-ph',
#  'astro-ph.CO astro-ph.HE hep-ph hep-th',
#  'astro-ph.CO astro-ph.HE hep-ph nucl-ex',
#  'astro-ph.CO astro-ph.HE hep-ph nucl-th',
#  'astro-ph.CO astro-ph.HE hep-th',
#  'astro-ph.CO astro-ph.HE nlin.CD physics.plasm-ph',
#  'astro-ph.CO astro-ph.HE nucl-ex',
#  'astro-ph.CO astro-ph.HE nucl-th',
#  'astro-ph.CO astro-ph.HE physics.data-an',
#  'astro-ph.CO astro-ph.HE physics.data-an stat.AP',
#  'astro-ph.CO astro-ph.HE physics.flu-dyn',
#  'astro-ph.CO astro-ph.HE physics.flu-dyn physics.plasm-ph physics.space-ph',
#  'astro-ph.CO astro-ph.HE physics.plasm-ph',
#  'astro-ph.CO astro-ph.HE stat.ML',
#  'astro-ph.CO astro-ph.IM',
#  'astro-ph.CO astro-ph.IM astro-ph.SR',
#  'astro-ph.CO astro-ph.IM astro-ph.SR gr-qc hep-ph',
#  'astro-ph.CO astro-ph.IM cond-mat.dis-nn',
#  'astro-ph.CO astro-ph.IM cond-mat.str-el hep-ex hep-ph',
#  'astro-ph.CO astro-ph.IM cs.AI cs.CV cs.LG',
#  'astro-ph.CO astro-ph.IM cs.AI cs.LG',
#  'astro-ph.CO astro-ph.IM cs.CE',
#  'astro-ph.CO astro-ph.IM cs.CV',
#  'astro-ph.CO astro-ph.IM cs.CV cs.LG',
#  'astro-ph.CO astro-ph.IM cs.DB',
#  'astro-ph.CO astro-ph.IM cs.DC physics.comp-ph',
#  'astro-ph.CO astro-ph.IM cs.IT math.IT',
#  'astro-ph.CO astro-ph.IM cs.LG',
#  'astro-ph.CO astro-ph.IM cs.LG cs.NE',
#  'astro-ph.CO astro-ph.IM cs.LG eess.SP gr-qc',
#  'astro-ph.CO astro-ph.IM cs.LG gr-qc',
#  'astro-ph.CO astro-ph.IM cs.LG physics.comp-ph',
#  'astro-ph.CO astro-ph.IM cs.LG physics.data-an',
#  'astro-ph.CO astro-ph.IM cs.LG stat.ML',
#  'astro-ph.CO astro-ph.IM cs.NA math.AP math.NA physics.comp-ph',
#  'astro-ph.CO astro-ph.IM gr-qc',
#  'astro-ph.CO astro-ph.IM gr-qc hep-ex hep-ph',
#  'astro-ph.CO astro-ph.IM gr-qc hep-ex hep-th',
#  'astro-ph.CO astro-ph.IM gr-qc hep-ph',
#  'astro-ph.CO astro-ph.IM gr-qc hep-ph hep-th',
#  'astro-ph.CO astro-ph.IM gr-qc hep-th',
#  'astro-ph.CO astro-ph.IM gr-qc physics.comp-ph physics.data-an',
#  'astro-ph.CO astro-ph.IM gr-qc physics.data-an',
#  'astro-ph.CO astro-ph.IM hep-ex',
#  'astro-ph.CO astro-ph.IM hep-ex hep-ph',
#  'astro-ph.CO astro-ph.IM hep-ex hep-ph physics.ins-det',
#  'astro-ph.CO astro-ph.IM hep-ex nucl-ex',
#  'astro-ph.CO astro-ph.IM hep-ex physics.ins-det',
#  'astro-ph.CO astro-ph.IM hep-ph',
#  'astro-ph.CO astro-ph.IM hep-ph hep-th',
#  'astro-ph.CO astro-ph.IM hep-ph physics.data-an',
#  'astro-ph.CO astro-ph.IM hep-ph physics.data-an stat.ML',
#  'astro-ph.CO astro-ph.IM hep-ph physics.ins-det',
#  'astro-ph.CO astro-ph.IM hep-ph physics.ins-det physics.optics',
#  'astro-ph.CO astro-ph.IM hep-th',
#  'astro-ph.CO astro-ph.IM hep-th physics.data-an',
#  'astro-ph.CO astro-ph.IM math-ph math.MP physics.comp-ph physics.data-an',
#  'astro-ph.CO astro-ph.IM math.AT',
#  'astro-ph.CO astro-ph.IM nlin.AO',
#  'astro-ph.CO astro-ph.IM nucl-th',
#  'astro-ph.CO astro-ph.IM physics.ao-ph',
#  'astro-ph.CO astro-ph.IM physics.atom-ph',
#  'astro-ph.CO astro-ph.IM physics.atom-ph quant-ph',
#  'astro-ph.CO astro-ph.IM physics.comp-ph',
#  'astro-ph.CO astro-ph.IM physics.comp-ph physics.data-an',
#  'astro-ph.CO astro-ph.IM physics.comp-ph physics.flu-dyn',
#  'astro-ph.CO astro-ph.IM physics.data-an',
#  'astro-ph.CO astro-ph.IM physics.data-an stat.AP',
#  'astro-ph.CO astro-ph.IM physics.data-an stat.ML',
#  'astro-ph.CO astro-ph.IM physics.flu-dyn',
#  'astro-ph.CO astro-ph.IM physics.ins-det',
#  'astro-ph.CO astro-ph.IM physics.pop-ph',
#  'astro-ph.CO astro-ph.IM q-bio.QM',
#  'astro-ph.CO astro-ph.IM stat.AP',
#  'astro-ph.CO astro-ph.IM stat.AP stat.CO',
#  'astro-ph.CO astro-ph.IM stat.CO',
#  'astro-ph.CO astro-ph.IM stat.CO stat.ME',
#  'astro-ph.CO astro-ph.IM stat.ME',
#  'astro-ph.CO astro-ph.IM stat.ME stat.ML',
#  'astro-ph.CO astro-ph.IM stat.ML',
#  'astro-ph.CO astro-ph.SR',
#  'astro-ph.CO astro-ph.SR cond-mat.stat-mech hep-ph',
#  'astro-ph.CO astro-ph.SR gr-qc',
#  'astro-ph.CO astro-ph.SR gr-qc hep-ph',
#  'astro-ph.CO astro-ph.SR gr-qc hep-ph hep-th',
#  'astro-ph.CO astro-ph.SR gr-qc hep-th',
#  'astro-ph.CO astro-ph.SR gr-qc physics.ins-det physics.space-ph',
#  'astro-ph.CO astro-ph.SR hep-ph',
#  'astro-ph.CO astro-ph.SR hep-ph nucl-th',
#  'astro-ph.CO astro-ph.SR nucl-ex nucl-th',
#  'astro-ph.CO astro-ph.SR nucl-th',
#  'astro-ph.CO astro-ph.SR physics.atom-ph',
#  'astro-ph.CO astro-ph.SR physics.plasm-ph',
#  'astro-ph.CO cond-mat.dis-nn cond-mat.stat-mech gr-qc math-ph math.MP',
#  'astro-ph.CO cond-mat.dis-nn hep-th',
#  'astro-ph.CO cond-mat.mtrl-sci cond-mat.soft hep-ph hep-th',
#  'astro-ph.CO cond-mat.other',
#  'astro-ph.CO cond-mat.other gr-qc hep-th',
#  'astro-ph.CO cond-mat.other hep-ph hep-th quant-ph',
#  'astro-ph.CO cond-mat.other hep-ph quant-ph',
#  'astro-ph.CO cond-mat.other physics.ins-det',
#  'astro-ph.CO cond-mat.quant-gas',
#  'astro-ph.CO cond-mat.quant-gas gr-qc hep-ph',
#  'astro-ph.CO cond-mat.quant-gas hep-ph',
#  'astro-ph.CO cond-mat.quant-gas hep-ph physics.comp-ph',
#  'astro-ph.CO cond-mat.quant-gas hep-ph quant-ph',
#  'astro-ph.CO cond-mat.quant-gas nlin.PS',
#  'astro-ph.CO cond-mat.soft',
#  'astro-ph.CO cond-mat.stat-mech',
#  'astro-ph.CO cond-mat.stat-mech gr-qc',
#  'astro-ph.CO cond-mat.stat-mech gr-qc hep-th',
#  'astro-ph.CO cond-mat.stat-mech hep-ph',
#  'astro-ph.CO cond-mat.stat-mech math-ph math.MP',
#  'astro-ph.CO cond-mat.stat-mech physics.flu-dyn',
#  'astro-ph.CO cond-mat.str-el',
#  'astro-ph.CO cond-mat.str-el hep-ph hep-th',
#  'astro-ph.CO cond-mat.str-el hep-ph quant-ph',
#  'astro-ph.CO cond-mat.supr-con hep-ex',
#  'astro-ph.CO cs.AI',
#  'astro-ph.CO cs.AI cs.GR cs.MA',
#  'astro-ph.CO cs.AI cs.LG',
#  'astro-ph.CO cs.CE cs.PF',
#  'astro-ph.CO cs.CG',
#  'astro-ph.CO cs.CG physics.pop-ph',
#  'astro-ph.CO cs.CV',
#  'astro-ph.CO cs.CV cs.LG',
#  'astro-ph.CO cs.CV cs.LG stat.CO',
#  'astro-ph.CO cs.CV gr-qc',
#  'astro-ph.CO cs.CV stat.ML',
#  'astro-ph.CO cs.DC',
#  'astro-ph.CO cs.DC physics.comp-ph',
#  'astro-ph.CO cs.LG',
#  'astro-ph.CO cs.LG cs.NA',
#  'astro-ph.CO cs.LG eess.IV',
#  'astro-ph.CO cs.LG eess.SP',
#  'astro-ph.CO cs.LG gr-qc',
#  'astro-ph.CO cs.LG gr-qc hep-ph hep-th',
#  'astro-ph.CO cs.LG hep-ph',
#  'astro-ph.CO cs.LG hep-th math.AT',
#  'astro-ph.CO cs.LG physics.comp-ph',
#  'astro-ph.CO cs.LG physics.comp-ph physics.data-an',
#  'astro-ph.CO cs.LG stat.ML',
#  'astro-ph.CO cs.NA gr-qc math.NA',
#  'astro-ph.CO cs.NA math.AP math.NA physics.comp-ph',
#  'astro-ph.CO cs.NA math.NA',
#  'astro-ph.CO gr-qc',
#  'astro-ph.CO gr-qc hep-ex',
#  'astro-ph.CO gr-qc hep-ex hep-ph',
#  'astro-ph.CO gr-qc hep-ex hep-ph hep-th',
#  'astro-ph.CO gr-qc hep-ex hep-ph physics.atom-ph',
#  'astro-ph.CO gr-qc hep-ex hep-ph physics.ins-det',
#  'astro-ph.CO gr-qc hep-ex hep-th',
#  'astro-ph.CO gr-qc hep-ex physics.atom-ph',
#  'astro-ph.CO gr-qc hep-lat hep-ph',
#  'astro-ph.CO gr-qc hep-lat hep-ph hep-th',
#  'astro-ph.CO gr-qc hep-ph',
#  'astro-ph.CO gr-qc hep-ph hep-th',
#  'astro-ph.CO gr-qc hep-ph hep-th math-ph math.MP',
#  'astro-ph.CO gr-qc hep-ph hep-th nucl-th',
#  'astro-ph.CO gr-qc hep-ph hep-th nucl-th physics.atom-ph',
#  'astro-ph.CO gr-qc hep-ph hep-th physics.atom-ph',
#  'astro-ph.CO gr-qc hep-ph hep-th physics.hist-ph',
#  'astro-ph.CO gr-qc hep-ph hep-th physics.ins-det',
#  'astro-ph.CO gr-qc hep-ph hep-th physics.space-ph',
#  'astro-ph.CO gr-qc hep-ph hep-th quant-ph',
#  'astro-ph.CO gr-qc hep-ph math-ph math.MP',
#  'astro-ph.CO gr-qc hep-ph nucl-th',
#  'astro-ph.CO gr-qc hep-ph physics.atom-ph',
#  'astro-ph.CO gr-qc hep-ph physics.comp-ph',
#  'astro-ph.CO gr-qc hep-ph physics.flu-dyn',
#  'astro-ph.CO gr-qc hep-ph physics.hist-ph',
#  'astro-ph.CO gr-qc hep-ph physics.plasm-ph',
#  'astro-ph.CO gr-qc hep-ph physics.pop-ph',
#  'astro-ph.CO gr-qc hep-ph physics.space-ph',
#  'astro-ph.CO gr-qc hep-ph quant-ph',
#  'astro-ph.CO gr-qc hep-th',
#  'astro-ph.CO gr-qc hep-th math-ph math.MP',
#  'astro-ph.CO gr-qc hep-th math.DG',
#  'astro-ph.CO gr-qc hep-th nlin.PS',
#  'astro-ph.CO gr-qc hep-th physics.atom-ph',
#  'astro-ph.CO gr-qc hep-th physics.comp-ph',
#  'astro-ph.CO gr-qc hep-th physics.data-an',
#  'astro-ph.CO gr-qc hep-th physics.hist-ph',
#  'astro-ph.CO gr-qc hep-th physics.plasm-ph',
#  'astro-ph.CO gr-qc hep-th quant-ph',
#  'astro-ph.CO gr-qc math-ph math.MP',
#  'astro-ph.CO gr-qc math-ph math.MP nlin.SI',
#  'astro-ph.CO gr-qc math.AP',
#  'astro-ph.CO gr-qc nlin.CD',
#  'astro-ph.CO gr-qc nucl-ex',
#  'astro-ph.CO gr-qc physics.atom-ph',
#  'astro-ph.CO gr-qc physics.atom-ph quant-ph',
#  'astro-ph.CO gr-qc physics.comp-ph',
#  'astro-ph.CO gr-qc physics.comp-ph physics.ed-ph',
#  'astro-ph.CO gr-qc physics.data-an',
#  'astro-ph.CO gr-qc physics.hist-ph',
#  'astro-ph.CO gr-qc physics.optics',
#  'astro-ph.CO gr-qc physics.plasm-ph',
#  'astro-ph.CO gr-qc physics.pop-ph',
#  'astro-ph.CO gr-qc physics.soc-ph',
#  'astro-ph.CO gr-qc quant-ph',
#  'astro-ph.CO hep-ex',
#  'astro-ph.CO hep-ex hep-lat hep-ph',
#  'astro-ph.CO hep-ex hep-ph',
#  'astro-ph.CO hep-ex hep-ph hep-th',
#  'astro-ph.CO hep-ex hep-ph nucl-ex',
#  'astro-ph.CO hep-ex hep-ph nucl-ex physics.ins-det',
#  'astro-ph.CO hep-ex hep-ph nucl-th',
#  'astro-ph.CO hep-ex hep-ph physics.atom-ph',
#  'astro-ph.CO hep-ex hep-ph physics.ins-det',
#  'astro-ph.CO hep-ex hep-th',
#  'astro-ph.CO hep-ex nucl-ex',
#  'astro-ph.CO hep-ex nucl-ex physics.ins-det',
#  'astro-ph.CO hep-ex physics.acc-ph',
#  'astro-ph.CO hep-ex physics.acc-ph physics.data-an',
#  'astro-ph.CO hep-ex physics.atom-ph',
#  'astro-ph.CO hep-ex physics.data-an',
#  'astro-ph.CO hep-ex physics.ins-det',
#  'astro-ph.CO hep-lat',
#  'astro-ph.CO hep-lat hep-ph',
#  'astro-ph.CO hep-lat hep-th',
#  'astro-ph.CO hep-ph',
#  'astro-ph.CO hep-ph hep-th',
#  'astro-ph.CO hep-ph hep-th nlin.PS',
#  'astro-ph.CO hep-ph hep-th nucl-th physics.atom-ph',
#  'astro-ph.CO hep-ph hep-th quant-ph',
#  'astro-ph.CO hep-ph math-ph math.MP',
#  'astro-ph.CO hep-ph math-ph math.MP nucl-th',
#  'astro-ph.CO hep-ph nlin.PS',
#  'astro-ph.CO hep-ph nucl-ex',
#  'astro-ph.CO hep-ph nucl-ex nucl-th',
#  'astro-ph.CO hep-ph nucl-ex physics.ins-det',
#  'astro-ph.CO hep-ph nucl-th',
#  'astro-ph.CO hep-ph nucl-th physics.atom-ph',
#  'astro-ph.CO hep-ph physics.acc-ph',
#  'astro-ph.CO hep-ph physics.atom-ph',
#  'astro-ph.CO hep-ph physics.comp-ph',
#  'astro-ph.CO hep-ph physics.data-an',
#  'astro-ph.CO hep-ph physics.flu-dyn',
#  'astro-ph.CO hep-ph physics.hist-ph',
#  'astro-ph.CO hep-ph physics.ins-det',
#  'astro-ph.CO hep-ph physics.plasm-ph',
#  'astro-ph.CO hep-ph quant-ph',
#  'astro-ph.CO hep-th',
#  'astro-ph.CO hep-th math.AT',
#  'astro-ph.CO hep-th nucl-th',
#  'astro-ph.CO hep-th physics.data-an',
#  'astro-ph.CO hep-th physics.hist-ph',
#  'astro-ph.CO hep-th physics.plasm-ph',
#  'astro-ph.CO hep-th quant-ph',
#  'astro-ph.CO math-ph math.MP',
#  'astro-ph.CO math-ph math.MP nlin.CD',
#  'astro-ph.CO math-ph math.MP physics.comp-ph',
#  'astro-ph.CO math-ph math.MP physics.data-an',
#  'astro-ph.CO math.AT',
#  'astro-ph.CO math.AT math.GT',
#  'astro-ph.CO math.GT',
#  'astro-ph.CO math.NA',
#  'astro-ph.CO math.ST stat.AP stat.ME stat.TH',
#  'astro-ph.CO math.ST stat.AP stat.ML stat.TH',
#  'astro-ph.CO math.ST stat.TH',
#  'astro-ph.CO nlin.AO',
#  'astro-ph.CO nlin.CD',
#  'astro-ph.CO nlin.CD physics.flu-dyn',
#  'astro-ph.CO nlin.PS physics.plasm-ph',
#  'astro-ph.CO nucl-ex',
#  'astro-ph.CO nucl-ex nucl-th',
#  'astro-ph.CO nucl-ex nucl-th physics.data-an',
#  'astro-ph.CO nucl-th',
#  'astro-ph.CO physics.atm-clus',
#  'astro-ph.CO physics.atom-ph',
#  'astro-ph.CO physics.atom-ph physics.chem-ph',
#  'astro-ph.CO physics.bio-ph',
#  'astro-ph.CO physics.chem-ph',
#  'astro-ph.CO physics.class-ph',
#  'astro-ph.CO physics.class-ph physics.comp-ph',
#  'astro-ph.CO physics.comp-ph',
#  'astro-ph.CO physics.comp-ph physics.flu-dyn',
#  'astro-ph.CO physics.data-an',
#  'astro-ph.CO physics.data-an stat.ML',
#  'astro-ph.CO physics.ed-ph',
#  'astro-ph.CO physics.ed-ph physics.hist-ph',
#  'astro-ph.CO physics.flu-dyn',
#  'astro-ph.CO physics.flu-dyn physics.plasm-ph',
#  'astro-ph.CO physics.gen-ph',
#  'astro-ph.CO physics.geo-ph',
#  'astro-ph.CO physics.geo-ph physics.space-ph',
#  'astro-ph.CO physics.hist-ph',
#  'astro-ph.CO physics.hist-ph physics.pop-ph',
#  'astro-ph.CO physics.ins-det',
#  'astro-ph.CO physics.optics',
#  'astro-ph.CO physics.plasm-ph',
#  'astro-ph.CO physics.pop-ph',
#  'astro-ph.CO physics.space-ph',
#  'astro-ph.CO q-bio.OT',
#  'astro-ph.CO quant-ph',
#  'astro-ph.CO stat.AP',
#  'astro-ph.CO stat.AP stat.CO',
#  'astro-ph.CO stat.CO',
#  'astro-ph.CO stat.CO stat.ML',
#  'astro-ph.CO stat.ME',
#  'astro-ph.CO stat.ML',
#  'astro-ph.EP',
#  'astro-ph.EP astro-ph.CO',
#  'astro-ph.EP astro-ph.CO astro-ph.GA',
#  'astro-ph.EP astro-ph.CO astro-ph.GA astro-ph.HE astro-ph.SR',
#  'astro-ph.EP astro-ph.CO astro-ph.GA astro-ph.HE physics.ao-ph physics.geo-ph q-bio.PE',
#  'astro-ph.EP astro-ph.CO astro-ph.GA astro-ph.IM',
#  'astro-ph.EP astro-ph.CO astro-ph.GA astro-ph.IM astro-ph.SR',
#  'astro-ph.EP astro-ph.CO astro-ph.GA astro-ph.SR',
#  'astro-ph.EP astro-ph.CO astro-ph.GA gr-qc hep-ph hep-th',
#  'astro-ph.EP astro-ph.CO astro-ph.HE gr-qc',
#  'astro-ph.EP astro-ph.CO astro-ph.HE nlin.CD physics.comp-ph',
#  'astro-ph.EP astro-ph.CO astro-ph.IM',
#  'astro-ph.EP astro-ph.CO astro-ph.IM gr-qc',
#  'astro-ph.EP astro-ph.CO astro-ph.SR',
#  'astro-ph.EP astro-ph.CO gr-qc',
#  'astro-ph.EP astro-ph.CO gr-qc hep-ph',
#  'astro-ph.EP astro-ph.CO gr-qc hep-th',
#  'astro-ph.EP astro-ph.CO hep-ph',
#  'astro-ph.EP astro-ph.CO physics.ao-ph physics.geo-ph',
#  'astro-ph.EP astro-ph.GA',
#  'astro-ph.EP astro-ph.GA astro-ph.HE',
#  'astro-ph.EP astro-ph.GA astro-ph.HE astro-ph.IM',
#  'astro-ph.EP astro-ph.GA astro-ph.HE astro-ph.IM astro-ph.SR',
#  'astro-ph.EP astro-ph.GA astro-ph.HE astro-ph.SR',
#  'astro-ph.EP astro-ph.GA astro-ph.HE physics.ao-ph',
#  'astro-ph.EP astro-ph.GA astro-ph.HE physics.space-ph',
#  'astro-ph.EP astro-ph.GA astro-ph.IM',
#  'astro-ph.EP astro-ph.GA astro-ph.IM astro-ph.SR',
#  'astro-ph.EP astro-ph.GA astro-ph.IM astro-ph.SR cs.LG',
#  'astro-ph.EP astro-ph.GA astro-ph.IM astro-ph.SR gr-qc',
#  'astro-ph.EP astro-ph.GA astro-ph.IM astro-ph.SR physics.optics',
#  'astro-ph.EP astro-ph.GA astro-ph.IM astro-ph.SR physics.pop-ph',
#  'astro-ph.EP astro-ph.GA astro-ph.IM math.NA',
#  'astro-ph.EP astro-ph.GA astro-ph.IM nlin.CD',
#  'astro-ph.EP astro-ph.GA astro-ph.IM physics.comp-ph',
#  'astro-ph.EP astro-ph.GA astro-ph.IM physics.geo-ph',
#  'astro-ph.EP astro-ph.GA astro-ph.SR',
#  'astro-ph.EP astro-ph.GA astro-ph.SR gr-qc',
#  'astro-ph.EP astro-ph.GA astro-ph.SR math-ph math.MP',
#  'astro-ph.EP astro-ph.GA astro-ph.SR nlin.CD',
#  'astro-ph.EP astro-ph.GA astro-ph.SR nlin.CD physics.flu-dyn',
#  'astro-ph.EP astro-ph.GA astro-ph.SR physics.atm-clus physics.chem-ph',
#  'astro-ph.EP astro-ph.GA astro-ph.SR physics.atom-ph',
#  'astro-ph.EP astro-ph.GA astro-ph.SR physics.class-ph physics.space-ph',
#  'astro-ph.EP astro-ph.GA astro-ph.SR physics.flu-dyn',
#  'astro-ph.EP astro-ph.GA astro-ph.SR physics.flu-dyn physics.plasm-ph',
#  'astro-ph.EP astro-ph.GA astro-ph.SR physics.geo-ph',
#  'astro-ph.EP astro-ph.GA astro-ph.SR physics.space-ph',
#  'astro-ph.EP astro-ph.GA cond-mat.soft',
#  'astro-ph.EP astro-ph.GA gr-qc',
#  'astro-ph.EP astro-ph.GA gr-qc physics.class-ph physics.data-an',
#  'astro-ph.EP astro-ph.GA hep-ph',
#  'astro-ph.EP astro-ph.GA math.DS',
#  'astro-ph.EP astro-ph.GA nlin.PS',
#  'astro-ph.EP astro-ph.GA physics.ao-ph',
#  'astro-ph.EP astro-ph.GA physics.ao-ph physics.flu-dyn',
#  'astro-ph.EP astro-ph.GA physics.atm-clus',
#  'astro-ph.EP astro-ph.GA physics.bio-ph physics.geo-ph q-bio.PE',
#  'astro-ph.EP astro-ph.GA physics.comp-ph',
#  'astro-ph.EP astro-ph.GA physics.comp-ph physics.flu-dyn',
#  'astro-ph.EP astro-ph.GA physics.geo-ph',
#  'astro-ph.EP astro-ph.GA physics.geo-ph q-bio.PE',
#  'astro-ph.EP astro-ph.GA q-bio.PE',
#  'astro-ph.EP astro-ph.HE',
#  'astro-ph.EP astro-ph.HE astro-ph.IM',
#  'astro-ph.EP astro-ph.HE astro-ph.IM astro-ph.SR',
#  'astro-ph.EP astro-ph.HE astro-ph.IM physics.space-ph',
#  'astro-ph.EP astro-ph.HE astro-ph.SR',
#  'astro-ph.EP astro-ph.HE astro-ph.SR physics.ao-ph physics.bio-ph physics.geo-ph physics.space-ph q-bio.PE',
#  'astro-ph.EP astro-ph.HE astro-ph.SR physics.ao-ph physics.geo-ph',
#  'astro-ph.EP astro-ph.HE astro-ph.SR physics.ao-ph physics.space-ph',
#  'astro-ph.EP astro-ph.HE astro-ph.SR physics.ao-ph q-bio.PE',
#  'astro-ph.EP astro-ph.HE astro-ph.SR physics.bio-ph physics.space-ph',
#  'astro-ph.EP astro-ph.HE astro-ph.SR physics.chem-ph',
#  'astro-ph.EP astro-ph.HE astro-ph.SR physics.flu-dyn',
#  'astro-ph.EP astro-ph.HE astro-ph.SR physics.flu-dyn physics.plasm-ph',
#  'astro-ph.EP astro-ph.HE astro-ph.SR physics.geo-ph q-bio.PE',
#  'astro-ph.EP astro-ph.HE astro-ph.SR physics.space-ph',
#  'astro-ph.EP astro-ph.HE gr-qc',
#  'astro-ph.EP astro-ph.HE hep-ph',
#  'astro-ph.EP astro-ph.HE hep-ph nucl-th',
#  'astro-ph.EP astro-ph.HE hep-ph physics.ao-ph',
#  'astro-ph.EP astro-ph.HE physics.ao-ph',
#  'astro-ph.EP astro-ph.HE physics.ao-ph physics.bio-ph physics.geo-ph q-bio.PE',
#  'astro-ph.EP astro-ph.HE physics.ao-ph physics.bio-ph q-bio.PE',
#  'astro-ph.EP astro-ph.HE physics.ao-ph physics.geo-ph physics.space-ph',
#  'astro-ph.EP astro-ph.HE physics.ao-ph physics.geo-ph q-bio.PE',
#  'astro-ph.EP astro-ph.HE physics.ao-ph q-bio.PE',
#  'astro-ph.EP astro-ph.HE physics.atom-ph',
#  'astro-ph.EP astro-ph.HE physics.geo-ph',
#  'astro-ph.EP astro-ph.HE physics.pop-ph',
#  'astro-ph.EP astro-ph.HE physics.space-ph',
#  'astro-ph.EP astro-ph.HE q-bio.PE',
#  'astro-ph.EP astro-ph.IM',
#  'astro-ph.EP astro-ph.IM astro-ph.SR',
#  'astro-ph.EP astro-ph.IM astro-ph.SR cs.LG',
#  'astro-ph.EP astro-ph.IM astro-ph.SR cs.PL',
#  'astro-ph.EP astro-ph.IM astro-ph.SR gr-qc',
#  ...]

# %% [markdown]
# ### Read record and transform its category

# %%
record = collection.find_one()
record
# Out:
# {'_id': ObjectId('64729c935ced617335d85d64'),
#  'id': '0704.0001',
#  'submitter': 'Pavel Nadolsky',
#  'authors': "C. Bal\\'azs, E. L. Berger, P. M. Nadolsky, C.-P. Yuan",
#  'title': 'Calculation of prompt diphoton production cross sections at Tevatron and\n  LHC energies',
#  'comments': '37 pages, 15 figures; published version',
#  'journal-ref': 'Phys.Rev.D76:013009,2007',
#  'doi': '10.1103/PhysRevD.76.013009',
#  'report-no': 'ANL-HEP-PR-07-12',
#  'categories': 'hep-ph',
#  'license': None,
#  'abstract': '  A fully differential calculation in perturbative quantum chromodynamics is\npresented for the production of massive photon pairs at hadron colliders. All\nnext-to-leading order perturbative contributions from quark-antiquark,\ngluon-(anti)quark, and gluon-gluon subprocesses are included, as well as\nall-orders resummation of initial-state gluon radiation valid at\nnext-to-next-to-leading logarithmic accuracy. The region of phase space is\nspecified in which the calculation is most reliable. Good agreement is\ndemonstrated with data from the Fermilab Tevatron, and predictions are made for\nmore detailed tests with CDF and DO data. Predictions are shown for\ndistributions of diphoton pairs produced at the energy of the Large Hadron\nCollider (LHC). Distributions of the diphoton pairs from the decay of a Higgs\nboson are contrasted with those produced from QCD processes at the LHC, showing\nthat enhanced sensitivity to the signal can be obtained with judicious\nselection of events.\n',
#  'versions': [{'version': 'v1', 'created': 'Mon, 2 Apr 2007 19:18:42 GMT'},
#   {'version': 'v2', 'created': 'Tue, 24 Jul 2007 20:10:27 GMT'}],
#  'update_date': '2008-11-26',
#  'authors_parsed': [['Balázs', 'C.', ''],
#   ['Berger', 'E. L.', ''],
#   ['Nadolsky', 'P. M.', ''],
#   ['Yuan', 'C. -P.', '']]}

# %%
record['categories'].split()
# Out:
# ['hep-ph']

# %%
le.transform(record['categories'].split())
# Out:
# array([79])
